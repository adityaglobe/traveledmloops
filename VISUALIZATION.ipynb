# %%
#pip install matplotlib seaborn plotly

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px 
import pandas as pd
import numpy as np

# %%
orders=pd.read_excel("superstore.xlsx")

# %%
#orders[orders["Order Date"].dt.year == 2015]

# %%
#DO=orders.groupby(orders["Order Date"].dt.month).agg({"Sales":"sum","Profit":'sum'})

# %%
#plt.plot(DO.index,DO["Sales"],label="Sales" , color="green")
#plt.plot(DO.index,DO["Profit"],label="Profit",color='pink')
#plt.legend()
#plt.title("Month Wise Sales and Profit")
#plt.grid()
#plt.xlabel("Month")
#plt.ylabel("Sales and Profit")
#plt.show()

# %%
#orders["Sub-Category"].unique()

# %%
#CO=orders.groupby("Sub-Category").agg({"Sales":"sum"})

# %%
#plt.figure(figsize=(20,4))
#plt.bar(x=CO.index,height=CO["Sales"],color='lightblue')
#for index , amount in enumerate(CO["Sales"]):
 #   plt.text(index,amount,str(round(amount/1000,1))+"K",ha='center')

# %%
#for index , amount in enumerate(CO["Sales"]):
 #   print(amount)

# %%
#plt.scatter(x=orders["Sales"],y=orders["Profit"])

# %%
#RO=orders.groupby("Region").agg({"Sales":"sum"})

# %%
#plt.pie(x=RO["Sales"],labels=RO.index ,  autopct="%1.1f%%")
#plt.show()

# %%
#plt.hist(orders["Quantity"],bins=10,rwidth=0.8)
#plt.show()

# %% [markdown]
# # Seaborn

# %%
#sns.get_dataset_names()

# %%
#iris=sns.load_data('iris')

# %%
#MO=orders.groupby(orders["Order Date"].dt.month).agg({"Sales":'sum'})

# %%
#sns.lineplot(x=MO.index,y=MO["Sales"],marker="o",color='grey')

# %%
#plt.figure(figsize=(20,5))
#sns.barplot(orders,x='Sub-Category',y='Sales',errorbar=('ci', 95))

# %%
#sns.scatterplot(orders,x='Sales',y='Profit',size="Profit")

# %%
#sns.regplot(orders,x='Sales',y='Profit')

# %%
#orders[["Sales","Profit"]].corr()
